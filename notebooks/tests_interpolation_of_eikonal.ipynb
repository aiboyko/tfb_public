# %% [markdown]
# # Tests of interpolation

# %%
# import pytorch_lightning as pl
import torch
import tntorch as tn

import matplotlib.pyplot as plt
# %matplotlib inline
import tensorfunbound as tfb
from tensorfunbound import eikonal2d, vis

# %%
import skfmm
import numpy.ma as ma

mask = plt.imread('newplan_512.png')
mask = (1-mask[:,:,0])>0
mask = mask.astype(float)
Nx, Ny = mask.shape
plt.imshow(mask)
plt.colorbar();

# %%
dat, fulldat = eikonal2d(mask, [280,200])
dat2, fulldat2 = eikonal2d(mask, [50,400])
dat3, fulldat3 = eikonal2d(mask, [300,370])

# %%
# result: ariphmetic average does not work, but geometric does

# %%
vis(fulldat)

# %%
vis(fulldat2)

# %%
vis(fulldat3)

# %%
p = 1.01
vis( ( (fulldat**p + fulldat2**p) )**(1/p)/2)

# %%
p = 5
vis( ( (fulldat**p + fulldat2**p) )**(1/p)/2)

# %% [markdown]
# interpretation:
# p=1 (ariphmetic averaging) takes the shortest path between 2 points, and this path becomes the new zero set
